# %% [markdown]
# # Cleaning and Preprocessing Data

# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# ### Read in CSVs

# %%
artist_df = pd.read_csv('artists.csv')
artist_df.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
data_by_artist_df = pd.read_csv('data_by_artist_o.csv')
data_by_artist_df.head()
# Out:
#            genres                                            artists  \
# 0  ['show tunes']                   "Cats" 1981 Original London Cast
# 1              []                          "Cats" 1983 Broadway Cast
# 2              []        "Fiddler On The Roof” Motion Picture Chorus
# 3              []     "Fiddler On The Roof” Motion Picture Orchestra
# 4              []  "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# ...

# %%
data_by_genre_df = pd.read_csv('data_by_genres_o.csv')
data_by_genre_df.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
data_by_year_df = pd.read_csv('data_by_year_o.csv')
data_by_year_df.head()
# Out:
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
# 2     1  1923      0.957247      0.577341  177942.362162  0.262406
# 3     1  1924      0.940200      0.549894  191046.707627  0.344347
# 4     1  1925      0.962607      0.573863  184986.924460  0.278594
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878  0.205710 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195  0.240720 -19.275282     0.116655  100.884521  0.535549
# 2          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 3          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
# 4          0.418297  0.237668 -14.146414     0.111918  115.521921  0.621929
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10
# 2    5.389189    0
# 3    0.661017   10
# ...

# %%
data_df = pd.read_csv('data_o.csv')
data_df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
# tracks_df = pd.read_csv('tracks.csv')
# tracks_df.head()

# %%
charts_df = pd.read_csv('charts.csv')
charts_df.head()
# Out:
#          date  rank               song                              artist  \
# 0  1958-08-04     1   Poor Little Fool                        Ricky Nelson
# 1  1958-08-04     2           Patricia       Perez Prado And His Orchestra
# 2  1958-08-04     3      Splish Splash                         Bobby Darin
# 3  1958-08-04     4  Hard Headed Woman  Elvis Presley With The Jordanaires
# 4  1958-08-04     5               When                         Kalin Twins
#
#    last-week  peak-rank  weeks-on-board
# 0        NaN          1               1
# 1        NaN          2               1
# 2        NaN          3               1
# 3        NaN          4               1
# 4        NaN          5               1

# %%
pd.to_datetime(charts_df['date'], format='%Y-%m-%d')
# Out:
# 0        1958-08-04
# 1        1958-08-04
# 2        1958-08-04
# 3        1958-08-04
# 4        1958-08-04
#             ...
# 327582   2021-05-15
# 327583   2021-05-15
# 327584   2021-05-15
# 327585   2021-05-15
# 327586   2021-05-15
# Name: date, Length: 327587, dtype: datetime64[ns]

# %%
#predict how long a song will be on the billboard and the highest number it will get to
# only do the past 10 years or so
# supervised

# %%
current_charts_df = charts_df.loc[pd.DatetimeIndex(charts_df['date']).year > 2019]
current_charts_df
# Out:
#               date  rank                               song  \
# 320387  2020-01-04     1    All I Want For Christmas Is You
# 320388  2020-01-04     2  Rockin' Around The Christmas Tree
# 320389  2020-01-04     3                   Jingle Bell Rock
# 320390  2020-01-04     4            A Holly Jolly Christmas
# 320391  2020-01-04     5                            Circles
# ...            ...   ...                                ...
# 327582  2021-05-15    96               If Pain Was A Person
# 327583  2021-05-15    97                              Tampa
# 327584  2021-05-15    98                              Hello
# 327585  2021-05-15    99                       Way Less Sad
# 327586  2021-05-15   100                           Thankful
#
#                                             artist  last-week  peak-rank  \
# 320387                                Mariah Carey        1.0          1
# 320388                                  Brenda Lee        2.0          2
# ...

# %%
data_df['artists'].loc[(data_df['name']=='All I Want For Christmas Is You')]
# Out:
# 90229     ['Mariah Carey']
# 153869       ['Glee Cast']
# Name: artists, dtype: object

# %%
for artist in data_df['artists']:
    artist.strip('['']')

# %%
data_df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...
